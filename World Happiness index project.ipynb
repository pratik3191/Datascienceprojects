# %% [markdown]
# # Problem Statement:-

# %% [markdown]
#     To build a regressor model which will predict the WHI ( World Happiness Index of a country). The WHI is the measure of the level of Happiness in a countries based on different parameters lile per capita income, life expectancy, trust in the governance etc

# %% [markdown]
# Loading the data from the local system

# %%
import pandas as pd
df=pd.read_csv("G:\Data science projects\DSData-master\DSData-master\happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# # Understanding dataset

# %% [raw]
# There are 12 columns in the dataset namely:
# 1) Country
# 2) Region
# 3) Happiness Rank
# 4) Happiness score
# 5) Standard error
# 6) Economy(GDP per capita)
# 7) Family
# 8) Health(life expectancy)
# 9) Freedom
# 10) Trust(Government corruption)
# 11) Generosity
# 12) Dystopia Residual
#
# Country: Name of the country
#
# Region: The sub region to which the country belongs to
#
# Happiness Rank: it is the rank of the happiness of the countries
#
# Happiness score: it is the score of happiness of the country
#
# standard error: is the score of error in calculating the value
#
# Economy: is the score of GDP of the country
#
# Health: is the score of life expectancy
#
# Freedom: is the score of freedom in the country
#
# Trust: is the score is how well the government deals with corruption
#
# Generosity : is the score of generosity in the country
#
# Dystopia residual: is the score which tells how well the country does in terms of the least happiest country

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # EDA
# Heat map

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %% [markdown]
# As country we have to predict the happiness on the basis of the happiness score we have no use of country, region, happiness rank as it does not play any significant role in the data so we should drop the columns

# %%
df.drop(['Country','Region','Happiness Rank'], axis=1, inplace=True)

# %%
df
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# # Correlation

# %% [raw]
# The columns that have positive correlation with our target variable are
# 1) Economy
# 2) Family
# 3) Health
# 4) Freedom
# 5) Trust
# 6)Generosity
# 7) Dystopia Residual
#
# The columns with negative correlation with our target variable are
# 1) Standard Error
#
# The columns with positive correlation play an important part in calculation of happiness score

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot= True, fmt ="f" )
plt.xticks(fontsize=18)
plt.yticks(fontsize=15)
plt.title("Variables summary")
plt.show()

# %%
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %% [markdown]
# From the above plotting we are determining the mean, standard deviation, maximum and minimum values of each of the columns. It can be used further for data cleaning

# %% [markdown]
# Total no of rows in the data set 158 and columns 9

# %% [markdown]
# # Now we use subplot and displot to check whether the data is normalised or not.

# %%
import itertools

cols=['Happiness Score','Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']
length=len(cols)
cs=["b","r","g","c","m","k","lime"]
fig=plt.figure(figsize=(13,25))

for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(4,2,j+1)
    ax=sns.distplot(df[i],color=k,rug=True)
    ax.set_facecolor("w")
    plt.axvline(df[i].mean(),linestyle="dashed",label="mean",color="k")
    plt.legend(loc="best")
    plt.title(i,color="navy")
    plt.xlabel("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-cef727e6e69a> in <module>
#       7
#       8 for i,j,k in itertools.zip_longest(cols,range(length),cs):
# ----> 9     plt.subplot(4,2,j+1)
#      10     ax=sns.distplot(df[i],color=k,rug=True)
#      11     ax.set_facecolor("w")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# ...

# %% [markdown]
# Observation:
# From above visualisation wecan understand that the data is not normalised

# %%
df.hist(edgecolor='red',linewidth=1.5,figsize(20,20))
# Out:
#   File "<ipython-input-21-1a1a97ac64cc>", line 1
#     df.hist(edgecolor='red',linewidth=1.5, figsize(20,20))
#                                            ^
# SyntaxError: positional argument follows keyword argument
